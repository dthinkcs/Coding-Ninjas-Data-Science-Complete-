# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline


df = pd.read_csv("amazon_jobs_dataset.csv")

df = df[(df['BASIC QUALIFICATIONS'].str.contains('Java')) | (df['BASIC QUALIFICATIONS'].str.contains('java'))]
# Out:
#       Unnamed: 0                                              Title  \
# 0              0                       Software Development Manager
# 1              1                      Software Development Engineer
# 2              2                      Software Development Engineer
# 3              3         Software Development Engineer - Amazon Lex
# 4              4         Software Development Engineer - Amazon Lex
# 5              5         Software Development Engineer - Amazon Lex
# 8              8                     Software Development Engineer
# 9              9    Software Development Manager - Amazon Cloud Cam
# 10            10  Software Development Engineer – Alexa Machine ...
# 13            13                  Senior Applied Robotics Scientist
# 14            14                                    DevOps Engineer
# 15            15                                      UI Developer
# 16            16         Sr. Software Development Engineer, AWS Lex
# ...

# %%
l = df['Posting_date']

d = {}
for i in l:
    s = i.split()
    d[int(s[2])] = d.get(int(s[2]),0) + 1
    
for i in range(2012,2019):
    print(i,d[i])
# Out:
# 2012 6
# 2013 2
# 2014 4
# 2015 25
# 2016 95
# 2017 1093
# 2018 1210
