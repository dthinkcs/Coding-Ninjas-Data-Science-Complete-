# %%
from sklearn import datasets
from sklearn import model_selection
from sklearn.linear_model import LinearRegression



import numpy as np

x = np.genfromtxt('train.csv', delimiter=',')
y_train = x[:, [10]]
x_train = x[:,0:10]

x_test = np.genfromtxt('test.csv', delimiter=',')

algo1 = LinearRegression()

algo1.fit(x_train, y_train)

y_pred = algo1.predict(x_test)
t = np.round(y_pred,5)


np.savetxt("predictions2.csv", t, delimiter=",", fmt='%.5f')

t
# Out:
# array([[105.52975],
#        [105.80392],
#        [178.60857],
#        [ 79.38288],
#        [ 52.95869],
#        [ 98.87264],
#        [150.71755],
#        [ 34.86515],
#        [113.13536],
#        [161.50184],
#        [135.86156],
#        [ 94.71592],
#        [138.48094],
#        [141.37442],
#        [158.76863],
#        [171.65289],
#        [106.44836],
#        [103.9266 ],
#        [ 95.38694],
#        [167.40118],
#        [166.53426],
#        [101.53465],
#        [252.45036],
#        [147.02259],
#        [214.78907],
#        [161.27557],
#        [210.61315],
#        [ 71.78092],
#        [189.65032],
#        [206.61343],
#        [219.98643],
#        [168.80193],
#        [116.84846],
#        [178.744  ],
#        [ 77.03247],
#        [ 59.54633],
#        [111.56738],
#        [156.95187],
#        [154.59591],
#        [198.94457],
#        [115.53884],
#        [153.46699],
#        [ 84.9618 ],
#        [113.70337],
#        [142.14156],
#        [147.3104 ],
#        [ 82.78072],
#        [ 77.89237],
#        [128.99006],
#        [261.58712],
#        [213.31188],
#        [243.98791],
#        [167.68132],
#        [183.69712],
#        [166.85927],
#        [202.1144 ],
#        [220.39236],
#        [172.40288],
#        [176.60898],
#        [109.04657],
#        [276.3779 ],
#        [ 90.99942],
#        [289.37221],
#        [119.56253],
#        [ 75.45688],
#        [180.78599],
#        [146.62093],
#        [156.42382],
#        [ 41.07904],
#        [247.90645],
#        [207.99121],
#        [ 90.09641],
#        [222.2417 ],
#        [189.86378],
#        [182.26954],
#        [164.39881],
#        [190.27067],
#        [105.44868],
#        [199.86136],
#        [245.79639],
#        [123.20281],
#        [119.41032],
#        [145.8662 ],
#        [206.19247],
#        [150.86282],
#        [142.23222],
#        [154.56875],
#        [115.29233],
#        [134.0781 ],
#        [118.42225],
#        [203.57676],
#        [170.66484],
#        [127.4098 ],
#        [ 57.13508],
#        [231.92227],
#        [185.20714],
#        [187.37495],
#        [ 83.55921],
#        [185.42586],
#        [217.34036],
#        [108.86715],
#        [ 80.98715],
#        [127.05524],
#        [242.00739],
#        [155.97234],
#        [125.67575],
#        [246.41236],
#        [234.96393],
#        [191.51298],
#        [168.33254],
#        [163.02965]])
