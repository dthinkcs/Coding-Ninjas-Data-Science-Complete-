# %%
# Client ID   7a2501e82b2cbc8ef84f
# Client Secret   3f5f1b7ab371c2a8cf085ade4a3388b31dc4d12d



import requests

data = {'client_id' : '7a2501e82b2cbc8ef84f', 'state' : 'abc123', 
        'redirect_uri' : 'https://www.google.com/',
        'scope' : 'repo'}
response = requests.get('https://github.com/login/oauth/authorize', params = data)

response.url
# Out:
# 'https://github.com/login?client_id=7a2501e82b2cbc8ef84f&return_to=%2Flogin%2Foauth%2Fauthorize%3Fclient_id%3D7a2501e82b2cbc8ef84f%26redirect_uri%3Dhttps%253A%252F%252Fwww.google.com%252F%26scope%3Drepo%26state%3Dabc123'

# %%
# e69d130369ad3ee5ef7c

d = {'code' : 'e69d130369ad3ee5ef7c', 
     'redirect_uri' : 'https://www.google.com/', 'state' : 'abc123', 'client_id' : '7a2501e82b2cbc8ef84f',
    'client_secret' : '3f5f1b7ab371c2a8cf085ade4a3388b31dc4d12d'}   

r = requests.post('https://github.com/login/oauth/access_token', data = d)

print(r.text)
# Out:
# tushartuteja 5
# Rawal27 13
# Sherawat42 15

# %%
#  5cc2be484fd3554244764c758a79f0af65604f6a

h = {'Authorization' : 'token 5cc2be484fd3554244764c758a79f0af65604f6a', 'Accept' :'application/vnd.github.baptiste-preview+json' }


for i in range(1,10):
    url = 'https://api.github.com/orgs/fossasia/repos?page=%s'%i
    r = requests.get(url, headers = h, params = {'type' : 'all'})  
    
    for i in r.json() :
        print(i['name'])
# Out:
# x-mario
# phimpme-android
# phimpme-drupal
# xmario_buildscript
# pslab-case
# meilix-systemlock
# fossasia10-drupal
# fossasia11-drupal
# blog.fossasia.org
# 2010.fossasia.org
# 2014.fossasia.org
# meilix
# phimpme-wordpress
# 2015.fossasia.org
# badge-magic-android
# api.fossasia.net
# directory.api.fossasia.net
# common.api.fossasia.net
# cmap.api.fossasia.net
# feed.api.freifunk.net
# feed.api.fossasia.net
# fossasia-communities
# sg18.sciencehack.asia
# gci14.fossasia.org
# fossasia-nodemailer
# 2011.fossasia.org
# 2012.fossasia.org
# labs.fossasia.org
# fossasia.net
# foss.vn
# libregraphics.asia
# perspektive89.com
# susi_smart_box
# hotelxoai.com
# yaydoc-artwork
# fossasia-companion-android
# loklak_webclient
# circle-knitting
# open-event-attendee-android
# 2018.fossasia.org
# open-event
# open-event-droidgen
# open-event-wsgen
# open-event-server
# knitweb
# knitpat
# knitlib
# pslab-expeyes
# timeline.api.fossasia.net
# 2016.fossasia.org
# fossasia.org
# pslab.io
# ...

# %%
for i in r.json() :
    #if i['fork'] == False :
        print(i['name'])
# Out:
# x-mario
# phimpme-android
# phimpme-drupal
# xmario_buildscript
# pslab-case
# meilix-systemlock
# fossasia10-drupal
# fossasia11-drupal
# blog.fossasia.org
# 2010.fossasia.org
# 2014.fossasia.org
# meilix
# phimpme-wordpress
# 2015.fossasia.org
# badge-magic-android
# api.fossasia.net
# directory.api.fossasia.net
# common.api.fossasia.net
# cmap.api.fossasia.net
# feed.api.freifunk.net
# feed.api.fossasia.net
# fossasia-communities
# sg18.sciencehack.asia
# gci14.fossasia.org
# fossasia-nodemailer
# 2011.fossasia.org
# 2012.fossasia.org
# labs.fossasia.org
# fossasia.net
# foss.vn
